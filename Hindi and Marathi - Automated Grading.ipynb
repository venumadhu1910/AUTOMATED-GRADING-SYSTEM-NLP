# %% [markdown]
# # Import required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
import torch
import nltk
from nltk.tokenize import word_tokenize

# %% [markdown]
# # Sample answer scripts

# %%
df = pd.read_excel("C://Users//ANESTHESIA//Downloads//questions_answer_key.xlsx")
df.head()
# Out:
#    Qno        Topic                                  Question in Hindi  \
# 0    1   Adaptation  कीड़ों की आंखों को संयुक्त आंखें क्यों कहा जाता है
# 1    2   Adaptation               छलावरण का उपयोग किस लिए किया जाता है
# 2    3   Adaptation            कुछ फूलों पर रंगीन डिज़ाइन क्यों होता है
# 3    4   Adaptation  रेगिस्तान में कम पानी में भी जिंदा रहने के लिए...
# 4    5  Circulatory         प्लेटलेट की संख्या कम हो जाने से क्या होगा
#
#                                Model Answer in Hindi  \
# 0                उनकी आंखों में हजारों लेंस होते हैं
# 1   छिपकर शिकार करने के लिए शिकारियों से खुद को ब...
# 2   ताकि कीड़ों को फूलों में मौजूद रस तक पहुँचने क...
# 3                        पत्ते कांटों में बदल गए हैं
# 4   जख्म होने पर थक्के ना ज़मने के कारण बहाव ज्याद...
#
#                                  Question in Marathi  \
# 0       कीटकांच्या डोळ्यांना संयुक्त डोळे का म्हणतात
# 1           छ्द्मावरणाचा उपयोग प्राणी कशासाठी करतात?
# 2              काही फुलांवर रंगीबेरंगी नक्षी का असते
# 3  वाळवंटातील झाडांनी कमी पाण्यात जगण्यासाठी पाना...
# 4  रक्तातील कोणता घटक ऑक्सिजन वाहून नेण्याचे काम ...
#
#                       Model Answer in Marathi
# 0          त्यांच्या डोळ्यात हजारो भिंग असतात
# 1                       स्वसंरक्षण आणि  शिकार
# 2   कीटकांना फुलातील रसाचा रस्ता दाखवण्यासाठी
# 3                पानांचे रुपांतर काट्यात झाले
# 4                                लाल रक्तपेशी

# %% [markdown]
# # NLP Tasks / Preprocessing

# %%
def tokenize_text(text):
    return word_tokenize(text.lower())

# %%
def pos_tagging(text):
    tokens = word_tokenize(text)
    tagged_tokens = pos_tag(tokens)
    return tagged_tokens

# %%
def ner(text):
    tokens = word_tokenize(text)
    tagged_tokens = pos_tag(tokens)
    named_entities = ne_chunk(tagged_tokens)
    return named_entities

# %%
def grade_response(student_answer, model_answer):
    if student_answer.strip() == model_answer.strip():
        return 1, []  
    else:
        return 0, []

# %%
from nltk import pos_tag
from nltk.chunk import ne_chunk

# %% [markdown]
# # Analysis

# %%
for index, row in df.iterrows():
    qno = row['Qno']
    student_response_hindi = row['Question in Hindi']
    model_answer_hindi = row['Model Answer in Hindi']
    student_response_marathi = row['Question in Marathi']
    model_answer_marathi = row['Model Answer in Marathi']
    

    pos_tags_hindi = pos_tagging(student_response_hindi)
    named_entities_hindi = ner(student_response_hindi)
    
    pos_tags_marathi = pos_tagging(student_response_marathi)
    named_entities_marathi = ner(student_response_marathi)

    score_hindi, mistakes_hindi = grade_response(student_response_hindi, model_answer_hindi)
    score_marathi, mistakes_marathi = grade_response(student_response_marathi, model_answer_marathi)
    
    # Print the results
    print(f"Question {qno}:")
    print("Hindi - Student Response:", student_response_hindi)
    print("       Model Answer:", model_answer_hindi)
    print("       Hindi Score:", score_hindi)
    print("       Hindi Mistakes:", mistakes_hindi)
    print("       POS Tags (Hindi):", pos_tags_hindi)
    print("       Named Entities (Hindi):", named_entities_hindi)
    print("Marathi - Student Response:", student_response_marathi)
    print("         Model Answer:", model_answer_marathi)
    print("         Marathi Score:", score_marathi)
    print("         Marathi Mistakes:", mistakes_marathi)
    print("         POS Tags (Marathi):", pos_tags_marathi)
    print("         Named Entities (Marathi):", named_entities_marathi)
    print()
# Out:
# Question 1:
# Hindi - Student Response: कीड़ों की आंखों को संयुक्त आंखें क्यों कहा जाता है
#        Model Answer:  उनकी आंखों में हजारों लेंस होते हैं
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('कीड़ों', 'JJ'), ('की', 'NNP'), ('आंखों', 'NNP'), ('को', 'NNP'), ('संयुक्त', 'NNP'), ('आंखें', 'NNP'), ('क्यों', 'NNP'), ('कहा', 'NNP'), ('जाता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S
#   कीड़ों/JJ
#   की/NNP
#   आंखों/NNP
#   को/NNP
#   संयुक्त/NNP
#   आंखें/NNP
#   क्यों/NNP
#   कहा/NNP
#   जाता/NNP
#   है/NN)
# Marathi - Student Response: कीटकांच्या डोळ्यांना संयुक्त डोळे का म्हणतात
#          Model Answer:  त्यांच्या डोळ्यात हजारो भिंग असतात
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('कीटकांच्या', 'JJ'), ('डोळ्यांना', 'NNP'), ('संयुक्त', 'NNP'), ('डोळे', 'NNP'), ('का', 'NNP'), ('म्हणतात', 'NN')]
#          Named Entities (Marathi): (S
#   कीटकांच्या/JJ
#   डोळ्यांना/NNP
#   संयुक्त/NNP
#   डोळे/NNP
#   का/NNP
#   म्हणतात/NN)
#
# Question 2:
# Hindi - Student Response: छलावरण का उपयोग किस लिए किया जाता है
#        Model Answer:  छिपकर शिकार करने के लिए शिकारियों से खुद को बचाने के लिए
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('छलावरण', 'JJ'), ('का', 'NNP'), ('उपयोग', 'NNP'), ('किस', 'NNP'), ('लिए', 'NNP'), ('किया', 'NNP'), ('जाता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S
#   छलावरण/JJ
#   का/NNP
#   उपयोग/NNP
#   किस/NNP
#   लिए/NNP
#   किया/NNP
#   जाता/NNP
#   है/NN)
# Marathi - Student Response: छ्द्मावरणाचा उपयोग प्राणी कशासाठी करतात?
#          Model Answer: स्वसंरक्षण आणि  शिकार
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('छ्द्मावरणाचा', 'JJ'), ('उपयोग', 'NNP'), ('प्राणी', 'NNP'), ('कशासाठी', 'NNP'), ('करतात', 'NNP'), ('?', '.')]
#          Named Entities (Marathi): (S छ्द्मावरणाचा/JJ उपयोग/NNP प्राणी/NNP कशासाठी/NNP करतात/NNP ?/.)
#
# Question 3:
# Hindi - Student Response: कुछ फूलों पर रंगीन डिज़ाइन क्यों होता है
#        Model Answer:  ताकि कीड़ों को फूलों में मौजूद रस तक पहुँचने का रास्ता दिखे
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('कुछ', 'JJ'), ('फूलों', 'NNP'), ('पर', 'NNP'), ('रंगीन', 'NNP'), ('डिज़ाइन', 'NNP'), ('क्यों', 'NNP'), ('होता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S
#   कुछ/JJ
#   फूलों/NNP
#   पर/NNP
#   रंगीन/NNP
#   डिज़ाइन/NNP
#   क्यों/NNP
#   होता/NNP
#   है/NN)
# Marathi - Student Response: काही फुलांवर रंगीबेरंगी नक्षी का असते
#          Model Answer:  कीटकांना फुलातील रसाचा रस्ता दाखवण्यासाठी
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('काही', 'JJ'), ('फुलांवर', 'NNP'), ('रंगीबेरंगी', 'NNP'), ('नक्षी', 'NNP'), ('का', 'NNP'), ('असते', 'NN')]
#          Named Entities (Marathi): (S काही/JJ फुलांवर/NNP रंगीबेरंगी/NNP नक्षी/NNP का/NNP असते/NN)
#
# Question 4:
# Hindi - Student Response: रेगिस्तान में कम पानी में भी जिंदा रहने के लिए पौधों में क्या बदलाव हुआ है
#        Model Answer:  पत्ते कांटों में बदल गए हैं
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('रेगिस्तान', 'JJ'), ('में', 'NNP'), ('कम', 'NNP'), ('पानी', 'NNP'), ('में', 'NNP'), ('भी', 'NNP'), ('जिंदा', 'NNP'), ('रहने', 'NNP'), ('के', 'NNP'), ('लिए', 'NNP'), ('पौधों', 'NNP'), ('में', 'NNP'), ('क्या', 'NNP'), ('बदलाव', 'NNP'), ('हुआ', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S
#   रेगिस्तान/JJ
#   में/NNP
#   कम/NNP
#   पानी/NNP
#   में/NNP
#   भी/NNP
#   जिंदा/NNP
#   रहने/NNP
#   के/NNP
#   लिए/NNP
#   पौधों/NNP
#   में/NNP
#   क्या/NNP
#   बदलाव/NNP
#   हुआ/NNP
#   है/NN)
# Marathi - Student Response: वाळवंटातील झाडांनी कमी पाण्यात जगण्यासाठी पानांमध्ये काय बदल केला
#          Model Answer:  पानांचे रुपांतर काट्यात झाले
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('वाळवंटातील', 'JJ'), ('झाडांनी', 'NNP'), ('कमी', 'NNP'), ('पाण्यात', 'NNP'), ('जगण्यासाठी', 'NNP'), ('पानांमध्ये', 'NNP'), ('काय', 'NNP'), ('बदल', 'NNP'), ('केला', 'NN')]
#          Named Entities (Marathi): (S
#   वाळवंटातील/JJ
#   झाडांनी/NNP
#   कमी/NNP
#   पाण्यात/NNP
#   जगण्यासाठी/NNP
#   पानांमध्ये/NNP
#   काय/NNP
#   बदल/NNP
#   केला/NN)
#
# Question 5:
# Hindi - Student Response: प्लेटलेट की संख्या कम हो जाने से क्या होगा
#        Model Answer:  जख्म होने पर थक्के ना ज़मने के कारण बहाव ज्यादा होगा
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('प्लेटलेट', 'JJ'), ('की', 'NNP'), ('संख्या', 'NNP'), ('कम', 'NNP'), ('हो', 'NNP'), ('जाने', 'NNP'), ('से', 'NNP'), ('क्या', 'NNP'), ('होगा', 'NN')]
#        Named Entities (Hindi): (S
#   प्लेटलेट/JJ
#   की/NNP
#   संख्या/NNP
#   कम/NNP
#   हो/NNP
#   जाने/NNP
#   से/NNP
#   क्या/NNP
#   होगा/NN)
# Marathi - Student Response: रक्तातील कोणता घटक ऑक्सिजन वाहून नेण्याचे काम करतो
#          Model Answer:  लाल रक्तपेशी
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('रक्तातील', 'JJ'), ('कोणता', 'NNP'), ('घटक', 'NNP'), ('ऑक्सिजन', 'NNP'), ('वाहून', 'NNP'), ('नेण्याचे', 'NNP'), ('काम', 'NNP'), ('करतो', 'NN')]
#          Named Entities (Marathi): (S
#   रक्तातील/JJ
#   कोणता/NNP
#   घटक/NNP
#   ऑक्सिजन/NNP
#   वाहून/NNP
#   नेण्याचे/NNP
#   काम/NNP
#   करतो/NN)
#
# Question 6:
# Hindi - Student Response: रक्त का कौनसा घटक ऑक्सीजन का वहन करता है
#        Model Answer:  लाल रक्त कणिका
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('रक्त', 'JJ'), ('का', 'NNP'), ('कौनसा', 'NNP'), ('घटक', 'NNP'), ('ऑक्सीजन', 'NNP'), ('का', 'NNP'), ('वहन', 'NNP'), ('करता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S
#   रक्त/JJ
#   का/NNP
#   कौनसा/NNP
#   घटक/NNP
#   ऑक्सीजन/NNP
#   का/NNP
#   वहन/NNP
#   करता/NNP
#   है/NN)
# Marathi - Student Response: रक्तातील कोणत्या घटकात मुख्यतः क्षार, प्रथिने, साखर, अन्य पोषकतत्वे असतात
#          Model Answer:  प्लाज्मा
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('रक्तातील', 'JJ'), ('कोणत्या', 'NNP'), ('घटकात', 'NNP'), ('मुख्यतः', 'NNP'), ('क्षार', 'NNP'), (',', ','), ('प्रथिने', 'NNP'), (',', ','), ('साखर', 'NNP'), (',', ','), ('अन्य', 'NNP'), ('पोषकतत्वे', 'NNP'), ('असतात', 'NN')]
#          Named Entities (Marathi): (S
#   रक्तातील/JJ
#   कोणत्या/NNP
#   घटकात/NNP
#   मुख्यतः/NNP
#   क्षार/NNP
#   ,/,
#   प्रथिने/NNP
#   ,/,
#   साखर/NNP
#   ,/,
#   अन्य/NNP
#   पोषकतत्वे/NNP
#   असतात/NN)
#
# Question 7:
# Hindi - Student Response: रक्त के किस हिस्से में मुख्यतः विटामिन, खनिज और कार्बोहाइड्रेट होता है
#        Model Answer:  प्लाज्मा
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('रक्त', 'JJ'), ('के', 'NNP'), ('किस', 'NNP'), ('हिस्से', 'NNP'), ('में', 'NNP'), ('मुख्यतः', 'NNP'), ('विटामिन', 'NNP'), (',', ','), ('खनिज', 'NNP'), ('और', 'NNP'), ('कार्बोहाइड्रेट', 'NNP'), ('होता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S
#   रक्त/JJ
#   के/NNP
#   किस/NNP
#   हिस्से/NNP
#   में/NNP
#   मुख्यतः/NNP
#   विटामिन/NNP
#   ,/,
#   खनिज/NNP
#   और/NNP
#   कार्बोहाइड्रेट/NNP
#   होता/NNP
#   है/NN)
# Marathi - Student Response: प्लेटलेटची संख्या कमी झाली तर काय होईल
#          Model Answer:  जखम झाल्यावर रक्ताच्या गुठळ्या होणार नाहीत आणि जास्त रक्तस्त्राव होईल
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('प्लेटलेटची', 'JJ'), ('संख्या', 'NNP'), ('कमी', 'NNP'), ('झाली', 'NNP'), ('तर', 'NNP'), ('काय', 'NNP'), ('होईल', 'NN')]
#          Named Entities (Marathi): (S प्लेटलेटची/JJ संख्या/NNP कमी/NNP झाली/NNP तर/NNP काय/NNP होईल/NN)
#
# Question 8:
# Hindi - Student Response: ह्रदय को रक्त पहुंचाने वाली रक्तवाहिनी बंद हो जाने से दिल का दौरा पड़ सकता है, क्यों
#        Model Answer:  रक्त में घुली ऑक्सीजन और पोषक तत्व ह्रदय के उस हिस्से तक नहीं पहुंचते हैं
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('ह्रदय', 'JJ'), ('को', 'NNP'), ('रक्त', 'NNP'), ('पहुंचाने', 'NNP'), ('वाली', 'NNP'), ('रक्तवाहिनी', 'NNP'), ('बंद', 'NNP'), ('हो', 'NNP'), ('जाने', 'NNP'), ('से', 'NNP'), ('दिल', 'NNP'), ('का', 'NNP'), ('दौरा', 'NNP'), ('पड़', 'NNP'), ('सकता', 'NNP'), ('है', 'NNP'), (',', ','), ('क्यों', 'NN')]
#        Named Entities (Hindi): (S
#   ह्रदय/JJ
#   को/NNP
#   रक्त/NNP
#   पहुंचाने/NNP
#   वाली/NNP
#   रक्तवाहिनी/NNP
#   बंद/NNP
#   हो/NNP
#   जाने/NNP
#   से/NNP
#   दिल/NNP
#   का/NNP
#   दौरा/NNP
#   पड़/NNP
#   सकता/NNP
#   है/NNP
#   ,/,
#   क्यों/NN)
# Marathi - Student Response: हृदयाला रक्त पुरवठा करणारी रक्तवाहिनी बंद पडल्यावर हार्ट ॲटॅक येऊ शकतो, कारण
#          Model Answer:  रक्तातील ऑक्सिजन आणि पोषणतत्वे हृदयाच्या त्या भागापर्यंत पोहचू शकत नाही
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('हृदयाला', 'JJ'), ('रक्त', 'NNP'), ('पुरवठा', 'NNP'), ('करणारी', 'NNP'), ('रक्तवाहिनी', 'NNP'), ('बंद', 'NNP'), ('पडल्यावर', 'NNP'), ('हार्ट', 'NNP'), ('ॲटॅक', 'NNP'), ('येऊ', 'NNP'), ('शकतो', 'NNP'), (',', ','), ('कारण', 'NN')]
#          Named Entities (Marathi): (S
#   हृदयाला/JJ
#   रक्त/NNP
#   पुरवठा/NNP
#   करणारी/NNP
#   रक्तवाहिनी/NNP
#   बंद/NNP
#   पडल्यावर/NNP
#   हार्ट/NNP
#   ॲटॅक/NNP
#   येऊ/NNP
#   शकतो/NNP
#   ,/,
#   कारण/NN)
#
# Question 9:
# Hindi - Student Response: आंखों में धूल चली जाने पर आंसू क्यों आ जाते हैं
#        Model Answer:  धूल के कण आंसुओं के साथ बाहर निकल आते है ताकि आंखों को हानि न पंहुचे
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('आंखों', 'JJ'), ('में', 'NNP'), ('धूल', 'NNP'), ('चली', 'NNP'), ('जाने', 'NNP'), ('पर', 'NNP'), ('आंसू', 'NNP'), ('क्यों', 'NNP'), ('आ', 'NNP'), ('जाते', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S
#   आंखों/JJ
#   में/NNP
#   धूल/NNP
#   चली/NNP
#   जाने/NNP
#   पर/NNP
#   आंसू/NNP
#   क्यों/NNP
#   आ/NNP
#   जाते/NNP
#   हैं/NN)
# Marathi - Student Response: डोळ्यात धुळ गेल्या नंतर डोळ्यातून अश्रु का येतात
#          Model Answer:  अश्रुंबरोबर धुळीचे कण वाहून जातात त्यामुळे डोळ्यांना नुकसान पोहचत नाही
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('डोळ्यात', 'JJ'), ('धुळ', 'NNP'), ('गेल्या', 'NNP'), ('नंतर', 'NNP'), ('डोळ्यातून', 'NNP'), ('अश्रु', 'NNP'), ('का', 'NNP'), ('येतात', 'NN')]
#          Named Entities (Marathi): (S
#   डोळ्यात/JJ
#   धुळ/NNP
#   गेल्या/NNP
#   नंतर/NNP
#   डोळ्यातून/NNP
#   अश्रु/NNP
#   का/NNP
#   येतात/NN)
#
# Question 10:
# Hindi - Student Response: प्रकाश किरणें सबसे पहले आंख के किस भाग से गुजरती हैं
#        Model Answer:  स्वच्छ मंडल कार्निया
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('प्रकाश', 'JJ'), ('किरणें', 'NNP'), ('सबसे', 'NNP'), ('पहले', 'NNP'), ('आंख', 'NNP'), ('के', 'NNP'), ('किस', 'NNP'), ('भाग', 'NNP'), ('से', 'NNP'), ('गुजरती', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S
#   प्रकाश/JJ
#   किरणें/NNP
#   सबसे/NNP
#   पहले/NNP
#   आंख/NNP
#   के/NNP
#   किस/NNP
#   भाग/NNP
#   से/NNP
#   गुजरती/NNP
#   हैं/NN)
# Marathi - Student Response: डोळ्याच्या कोणत्या भागातून परावर्तित प्रकाश किरणे सर्वात आधी जातात
#          Model Answer:  पारपटल कॉर्निया
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('डोळ्याच्या', 'JJ'), ('कोणत्या', 'NNP'), ('भागातून', 'NNP'), ('परावर्तित', 'NNP'), ('प्रकाश', 'NNP'), ('किरणे', 'NNP'), ('सर्वात', 'NNP'), ('आधी', 'NNP'), ('जातात', 'NN')]
#          Named Entities (Marathi): (S
#   डोळ्याच्या/JJ
#   कोणत्या/NNP
#   भागातून/NNP
#   परावर्तित/NNP
#   प्रकाश/NNP
#   किरणे/NNP
#   सर्वात/NNP
#   आधी/NNP
#   जातात/NN)
#
# Question 11:
# Hindi - Student Response: वस्तु का सफ़ेद होना क्या दर्शाता है
#        Model Answer:  वह सभी रंगों को परावर्तित करती है
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('वस्तु', 'JJ'), ('का', 'NNP'), ('सफ़ेद', 'NNP'), ('होना', 'NNP'), ('क्या', 'NNP'), ('दर्शाता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S वस्तु/JJ का/NNP सफ़ेद/NNP होना/NNP क्या/NNP दर्शाता/NNP है/NN)
# Marathi - Student Response: वस्तू दिसण्यासाठी आपल्याला प्रकाशाच्या कोणत्या गुणधर्माची मदत होते
#          Model Answer:  प्रकाशाचे परावर्तन
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('वस्तू', 'JJ'), ('दिसण्यासाठी', 'NNP'), ('आपल्याला', 'NNP'), ('प्रकाशाच्या', 'NNP'), ('कोणत्या', 'NNP'), ('गुणधर्माची', 'NNP'), ('मदत', 'NNP'), ('होते', 'NN')]
#          Named Entities (Marathi): (S
#   वस्तू/JJ
#   दिसण्यासाठी/NNP
#   आपल्याला/NNP
#   प्रकाशाच्या/NNP
#   कोणत्या/NNP
#   गुणधर्माची/NNP
#   मदत/NNP
#   होते/NN)
#
# Question 12:
# Hindi - Student Response: हर्मन स्नेलेन ने किसका आविष्कार किया था
#        Model Answer:  स्नेलेन चार्ट
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('हर्मन', 'JJ'), ('स्नेलेन', 'NNP'), ('ने', 'NNP'), ('किसका', 'NNP'), ('आविष्कार', 'NNP'), ('किया', 'NNP'), ('था', 'NN')]
#        Named Entities (Hindi): (S हर्मन/JJ स्नेलेन/NNP ने/NNP किसका/NNP आविष्कार/NNP किया/NNP था/NN)
# Marathi - Student Response: हर्मन स्नेलेन यांनी कशाचा शोध लावला होता
#          Model Answer:  स्नेलेन चार्ट
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('हर्मन', 'JJ'), ('स्नेलेन', 'NNP'), ('यांनी', 'NNP'), ('कशाचा', 'NNP'), ('शोध', 'NNP'), ('लावला', 'NNP'), ('होता', 'NN')]
#          Named Entities (Marathi): (S
#   हर्मन/JJ
#   स्नेलेन/NNP
#   यांनी/NNP
#   कशाचा/NNP
#   शोध/NNP
#   लावला/NNP
#   होता/NN)
#
# Question 13:
# Hindi - Student Response: गर्म चाय का कप कुछ समय बाद ठंडा क्यों हो जाता है
#        Model Answer:  ऊष्मा गर्म से ठंडी की ओर गति करती है
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('गर्म', 'JJ'), ('चाय', 'NNP'), ('का', 'NNP'), ('कप', 'NNP'), ('कुछ', 'NNP'), ('समय', 'NNP'), ('बाद', 'NNP'), ('ठंडा', 'NNP'), ('क्यों', 'NNP'), ('हो', 'NNP'), ('जाता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S
#   गर्म/JJ
#   चाय/NNP
#   का/NNP
#   कप/NNP
#   कुछ/NNP
#   समय/NNP
#   बाद/NNP
#   ठंडा/NNP
#   क्यों/NNP
#   हो/NNP
#   जाता/NNP
#   है/NN)
# Marathi - Student Response: गरम चहाचा कप काही वेळेनंतर थंड का होतो
#          Model Answer:  उष्णता गरम वस्तू कडून थंड वस्तू कडे जाते
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('गरम', 'JJ'), ('चहाचा', 'NNP'), ('कप', 'NNP'), ('काही', 'NNP'), ('वेळेनंतर', 'NNP'), ('थंड', 'NNP'), ('का', 'NNP'), ('होतो', 'NN')]
#          Named Entities (Marathi): (S
#   गरम/JJ
#   चहाचा/NNP
#   कप/NNP
#   काही/NNP
#   वेळेनंतर/NNP
#   थंड/NNP
#   का/NNP
#   होतो/NN)
#
# Question 14:
# Hindi - Student Response: कोयले के एक टुकड़े में आग लगाने से बाकी टुकड़े भी क्यों सुलग जाते हैं
#        Model Answer:  चालन से ऊष्मा सभी टुकड़ों में फ़ैल जाती है
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('कोयले', 'JJ'), ('के', 'NNP'), ('एक', 'NNP'), ('टुकड़े', 'NNP'), ('में', 'NNP'), ('आग', 'NNP'), ('लगाने', 'NNP'), ('से', 'NNP'), ('बाकी', 'NNP'), ('टुकड़े', 'NNP'), ('भी', 'NNP'), ('क्यों', 'NNP'), ('सुलग', 'NNP'), ('जाते', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S
#   कोयले/JJ
#   के/NNP
#   एक/NNP
#   टुकड़े/NNP
#   में/NNP
#   आग/NNP
#   लगाने/NNP
#   से/NNP
#   बाकी/NNP
#   टुकड़े/NNP
#   भी/NNP
#   क्यों/NNP
#   सुलग/NNP
#   जाते/NNP
#   हैं/NN)
# Marathi - Student Response: एक कोळसा पेटला तर उरलेले कोळसे ही का पेटतात
#          Model Answer:  वहनामुळे उष्णता सर्व कोळश्यांमध्ये पसरते
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('एक', 'JJ'), ('कोळसा', 'NNP'), ('पेटला', 'NNP'), ('तर', 'NNP'), ('उरलेले', 'NNP'), ('कोळसे', 'NNP'), ('ही', 'NNP'), ('का', 'NNP'), ('पेटतात', 'NN')]
#          Named Entities (Marathi): (S
#   एक/JJ
#   कोळसा/NNP
#   पेटला/NNP
#   तर/NNP
#   उरलेले/NNP
#   कोळसे/NNP
#   ही/NNP
#   का/NNP
#   पेटतात/NN)
#
# Question 15:
# Hindi - Student Response: द्रव और गैस में ऊष्मा स्थानान्तरण की प्रक्रिया को क्या कहते हैं
#        Model Answer:  संवहन
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('द्रव', 'JJ'), ('और', 'NNP'), ('गैस', 'NNP'), ('में', 'NNP'), ('ऊष्मा', 'NNP'), ('स्थानान्तरण', 'NNP'), ('की', 'NNP'), ('प्रक्रिया', 'NNP'), ('को', 'NNP'), ('क्या', 'NNP'), ('कहते', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S
#   द्रव/JJ
#   और/NNP
#   गैस/NNP
#   में/NNP
#   ऊष्मा/NNP
#   स्थानान्तरण/NNP
#   की/NNP
#   प्रक्रिया/NNP
#   को/NNP
#   क्या/NNP
#   कहते/NNP
#   हैं/NN)
# Marathi - Student Response: द्रव आणि वायूमध्ये होणाऱ्या उष्णता स्थानांतरणाच्या प्रक्रियेला काय म्हणतात
#          Model Answer:  अभिसरण
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('द्रव', 'JJ'), ('आणि', 'NNP'), ('वायूमध्ये', 'NNP'), ('होणाऱ्या', 'NNP'), ('उष्णता', 'NNP'), ('स्थानांतरणाच्या', 'NNP'), ('प्रक्रियेला', 'NNP'), ('काय', 'NNP'), ('म्हणतात', 'NN')]
#          Named Entities (Marathi): (S
#   द्रव/JJ
#   आणि/NNP
#   वायूमध्ये/NNP
#   होणाऱ्या/NNP
#   उष्णता/NNP
#   स्थानांतरणाच्या/NNP
#   प्रक्रियेला/NNP
#   काय/NNP
#   म्हणतात/NN)
#
# Question 16:
# Hindi - Student Response: कपड़े कौनसी प्रक्रिया से सूखते हैं
#        Model Answer:  वाष्पन
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('कपड़े', 'JJ'), ('कौनसी', 'NNP'), ('प्रक्रिया', 'NNP'), ('से', 'NNP'), ('सूखते', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S कपड़े/JJ कौनसी/NNP प्रक्रिया/NNP से/NNP सूखते/NNP हैं/NN)
# Marathi - Student Response: कपडे कोणत्या प्रक्रियेमुळे वाळतात
#          Model Answer:  बाष्पीभवन
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('कपडे', 'JJ'), ('कोणत्या', 'NNP'), ('प्रक्रियेमुळे', 'NNP'), ('वाळतात', 'NN')]
#          Named Entities (Marathi): (S कपडे/JJ कोणत्या/NNP प्रक्रियेमुळे/NNP वाळतात/NN)
#
# Question 17:
# Hindi - Student Response: पहाड़ पर चढ़ने के लिए सीधे रास्ते के बजाय हमेशा घुमावदार रास्ता क्यों बनाते हैं
#        Model Answer:  इससे रास्ते का झुकाव कम होकर चढ़ने में कम मेहनत लगती है
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('पहाड़', 'JJ'), ('पर', 'NNP'), ('चढ़ने', 'NNP'), ('के', 'NNP'), ('लिए', 'NNP'), ('सीधे', 'NNP'), ('रास्ते', 'NNP'), ('के', 'NNP'), ('बजाय', 'NNP'), ('हमेशा', 'NNP'), ('घुमावदार', 'NNP'), ('रास्ता', 'NNP'), ('क्यों', 'NNP'), ('बनाते', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S
#   पहाड़/JJ
#   पर/NNP
#   चढ़ने/NNP
#   के/NNP
#   लिए/NNP
#   सीधे/NNP
#   रास्ते/NNP
#   के/NNP
#   बजाय/NNP
#   हमेशा/NNP
#   घुमावदार/NNP
#   रास्ता/NNP
#   क्यों/NNP
#   बनाते/NNP
#   हैं/NN)
# Marathi - Student Response: घाटातले रस्ते नेहमी वळणावळणाचे असतात, कारण त्यामुळे
#          Model Answer:  रस्त्याचा कोन कमी होतो आणि कमी मेहनतीत वर चढता येते
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('घाटातले', 'JJ'), ('रस्ते', 'NNP'), ('नेहमी', 'NNP'), ('वळणावळणाचे', 'NNP'), ('असतात', 'NNP'), (',', ','), ('कारण', 'NNP'), ('त्यामुळे', 'NNP')]
#          Named Entities (Marathi): (S
#   घाटातले/JJ
#   रस्ते/NNP
#   नेहमी/NNP
#   वळणावळणाचे/NNP
#   असतात/NNP
#   ,/,
#   कारण/NNP
#   त्यामुळे/NNP)
#
# Question 18:
# Hindi - Student Response: उत्तोलक कितने प्रकार के होते हैं
#        Model Answer:  तीन
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('उत्तोलक', 'JJ'), ('कितने', 'NNP'), ('प्रकार', 'NNP'), ('के', 'NNP'), ('होते', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S उत्तोलक/JJ कितने/NNP प्रकार/NNP के/NNP होते/NNP हैं/NN)
# Marathi - Student Response: तरफेचे प्रकार किती
#          Model Answer:  तीन
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('तरफेचे', 'JJ'), ('प्रकार', 'NNP'), ('किती', 'NN')]
#          Named Entities (Marathi): (S तरफेचे/JJ प्रकार/NNP किती/NN)
#
# Question 19:
# Hindi - Student Response: उत्तोलक में जिस भुजा से प्रयास लगाया जाता है उसे क्या कहते हैं
#        Model Answer:  प्रयास भुजा
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('उत्तोलक', 'JJ'), ('में', 'NNP'), ('जिस', 'NNP'), ('भुजा', 'NNP'), ('से', 'NNP'), ('प्रयास', 'NNP'), ('लगाया', 'NNP'), ('जाता', 'NNP'), ('है', 'NNP'), ('उसे', 'NNP'), ('क्या', 'NNP'), ('कहते', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S
#   उत्तोलक/JJ
#   में/NNP
#   जिस/NNP
#   भुजा/NNP
#   से/NNP
#   प्रयास/NNP
#   लगाया/NNP
#   जाता/NNP
#   है/NNP
#   उसे/NNP
#   क्या/NNP
#   कहते/NNP
#   हैं/NN)
# Marathi - Student Response: तरफेमध्ये ज्या बाजूने बल लावले जाते त्या बाजूला काय म्हणतात
#          Model Answer:  बलभुजा
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('तरफेमध्ये', 'JJ'), ('ज्या', 'NNP'), ('बाजूने', 'NNP'), ('बल', 'NNP'), ('लावले', 'NNP'), ('जाते', 'NNP'), ('त्या', 'NNP'), ('बाजूला', 'NNP'), ('काय', 'NNP'), ('म्हणतात', 'NN')]
#          Named Entities (Marathi): (S
#   तरफेमध्ये/JJ
#   ज्या/NNP
#   बाजूने/NNP
#   बल/NNP
#   लावले/NNP
#   जाते/NNP
#   त्या/NNP
#   बाजूला/NNP
#   काय/NNP
#   म्हणतात/NN)
#
# Question 20:
# Hindi - Student Response: बिट्टू को घिरनी का इस्तेमाल करके 50 किलो की वस्तु को कम से कम बल लगाकर उठाना है. वह क्या करेगा
#        Model Answer:  स्थिर घिरनी के साथ एक से ज्यादा खिसकने वाली घिरनियों का इस्तेमाल
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('बिट्टू', 'JJ'), ('को', 'NNP'), ('घिरनी', 'NNP'), ('का', 'NNP'), ('इस्तेमाल', 'NNP'), ('करके', 'VBD'), ('50', 'CD'), ('किलो', 'NNP'), ('की', 'NNP'), ('वस्तु', 'NNP'), ('को', 'NNP'), ('कम', 'NNP'), ('से', 'NNP'), ('कम', 'NNP'), ('बल', 'NNP'), ('लगाकर', 'NNP'), ('उठाना', 'NNP'), ('है', 'NNP'), ('.', '.'), ('वह', 'VB'), ('क्या', 'JJ'), ('करेगा', 'NN')]
#        Named Entities (Hindi): (S
#   बिट्टू/JJ
#   को/NNP
#   घिरनी/NNP
#   का/NNP
#   इस्तेमाल/NNP
#   करके/VBD
#   50/CD
#   किलो/NNP
#   की/NNP
#   वस्तु/NNP
#   को/NNP
#   कम/NNP
#   से/NNP
#   कम/NNP
#   बल/NNP
#   लगाकर/NNP
#   उठाना/NNP
#   है/NNP
#   ./.
#   वह/VB
#   क्या/JJ
#   करेगा/NN)
# Marathi - Student Response: बिट्टूला कमीत-कमी बल लावून कप्पीच्या मदतीने 50 किलोची वस्तू उचलायची आहे. तो काय बरं करेल
#          Model Answer:  स्थिर कप्पीसोबत एकपेक्षा जास्त चल कप्प्या लावेल
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('बिट्टूला', 'JJ'), ('कमीत-कमी', 'JJ'), ('बल', 'NN'), ('लावून', 'NNP'), ('कप्पीच्या', 'NNP'), ('मदतीने', 'VBD'), ('50', 'CD'), ('किलोची', 'NNP'), ('वस्तू', 'NNP'), ('उचलायची', 'NNP'), ('आहे', 'NNP'), ('.', '.'), ('तो', 'VB'), ('काय', 'JJ'), ('बरं', 'NNP'), ('करेल', 'NN')]
#          Named Entities (Marathi): (S
#   बिट्टूला/JJ
#   कमीत-कमी/JJ
#   बल/NN
#   लावून/NNP
#   कप्पीच्या/NNP
#   मदतीने/VBD
#   50/CD
#   किलोची/NNP
#   वस्तू/NNP
#   उचलायची/NNP
#   आहे/NNP
#   ./.
#   तो/VB
#   काय/JJ
#   बरं/NNP
#   करेल/NN)
#
# Question 21:
# Hindi - Student Response: मानव कंकाल किससे बना होता है
#        Model Answer:  हड्डियों से
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('मानव', 'JJ'), ('कंकाल', 'NNP'), ('किससे', 'NNP'), ('बना', 'NNP'), ('होता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S मानव/JJ कंकाल/NNP किससे/NNP बना/NNP होता/NNP है/NN)
# Marathi - Student Response: मानवी सांगाडा कशाचा बनलेला आहे
#          Model Answer:  हाडांचा
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('मानवी', 'JJ'), ('सांगाडा', 'NNP'), ('कशाचा', 'NNP'), ('बनलेला', 'NNP'), ('आहे', 'NN')]
#          Named Entities (Marathi): (S मानवी/JJ सांगाडा/NNP कशाचा/NNP बनलेला/NNP आहे/NN)
#
# Question 22:
# Hindi - Student Response: हड्डियों के बींच जोड़ नहीं होते तो क्या होता
#        Model Answer:  हिलना डुलना असंभव होता
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('हड्डियों', 'JJ'), ('के', 'NNP'), ('बींच', 'NNP'), ('जोड़', 'NNP'), ('नहीं', 'NNP'), ('होते', 'NNP'), ('तो', 'NNP'), ('क्या', 'NNP'), ('होता', 'NN')]
#        Named Entities (Hindi): (S
#   हड्डियों/JJ
#   के/NNP
#   बींच/NNP
#   जोड़/NNP
#   नहीं/NNP
#   होते/NNP
#   तो/NNP
#   क्या/NNP
#   होता/NN)
# Marathi - Student Response: हाडांमध्ये सांधे नसते तर
#          Model Answer:  हालचाल करणे अशक्य झाले असते
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('हाडांमध्ये', 'JJ'), ('सांधे', 'NNP'), ('नसते', 'NNP'), ('तर', 'NN')]
#          Named Entities (Marathi): (S हाडांमध्ये/JJ सांधे/NNP नसते/NNP तर/NN)
#
# Question 23:
# Hindi - Student Response: एक वयस्क मनुष्य के कंकाल का वजन लगभग कितना होता है
#        Model Answer:  दस किग्रा
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('एक', 'JJ'), ('वयस्क', 'NNP'), ('मनुष्य', 'NNP'), ('के', 'NNP'), ('कंकाल', 'NNP'), ('का', 'NNP'), ('वजन', 'NNP'), ('लगभग', 'NNP'), ('कितना', 'NNP'), ('होता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S
#   एक/JJ
#   वयस्क/NNP
#   मनुष्य/NNP
#   के/NNP
#   कंकाल/NNP
#   का/NNP
#   वजन/NNP
#   लगभग/NNP
#   कितना/NNP
#   होता/NNP
#   है/NN)
# Marathi - Student Response: एका प्रौढ व्यक्तीच्या सांगाड्याचे वजन अंदाजे किती असते
#          Model Answer:  दस किग्रॅ
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('एका', 'JJ'), ('प्रौढ', 'NNP'), ('व्यक्तीच्या', 'NNP'), ('सांगाड्याचे', 'NNP'), ('वजन', 'NNP'), ('अंदाजे', 'NNP'), ('किती', 'NNP'), ('असते', 'NN')]
#          Named Entities (Marathi): (S
#   एका/JJ
#   प्रौढ/NNP
#   व्यक्तीच्या/NNP
#   सांगाड्याचे/NNP
#   वजन/NNP
#   अंदाजे/NNP
#   किती/NNP
#   असते/NN)
#
# Question 24:
# Hindi - Student Response: हम पैर को गोल क्यों हिला पाते हैं
#        Model Answer:  फीमर और श्रोणी के बॉल एंड सॉकेट जोड़ की वजह से
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('हम', 'JJ'), ('पैर', 'NNP'), ('को', 'NNP'), ('गोल', 'NNP'), ('क्यों', 'NNP'), ('हिला', 'NNP'), ('पाते', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S हम/JJ पैर/NNP को/NNP गोल/NNP क्यों/NNP हिला/NNP पाते/NNP हैं/NN)
# Marathi - Student Response: आपण आपला पाय गोलाकार कशामुळे हलवू शकतो
#          Model Answer:  फीमर आणि श्रोणी यांतील बॉल आणि सॉकेट सांधा
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('आपण', 'JJ'), ('आपला', 'NNP'), ('पाय', 'NNP'), ('गोलाकार', 'NNP'), ('कशामुळे', 'NNP'), ('हलवू', 'NNP'), ('शकतो', 'NN')]
#          Named Entities (Marathi): (S आपण/JJ आपला/NNP पाय/NNP गोलाकार/NNP कशामुळे/NNP हलवू/NNP शकतो/NN)
#
# Question 25:
# Hindi - Student Response: चाँद पर कोई किसी की आवाज क्यों नहीं सुन सकते
#        Model Answer:  वायुमंडल ना होने के कारण
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('चाँद', 'JJ'), ('पर', 'NNP'), ('कोई', 'NNP'), ('किसी', 'NNP'), ('की', 'NNP'), ('आवाज', 'NNP'), ('क्यों', 'NNP'), ('नहीं', 'NNP'), ('सुन', 'NNP'), ('सकते', 'NN')]
#        Named Entities (Hindi): (S
#   चाँद/JJ
#   पर/NNP
#   कोई/NNP
#   किसी/NNP
#   की/NNP
#   आवाज/NNP
#   क्यों/NNP
#   नहीं/NNP
#   सुन/NNP
#   सकते/NN)
# Marathi - Student Response: अंतराळवीर चंद्रावर एकमेकांचे आवाज का ऐकू शकत नाहीत
#          Model Answer:  कारण चंद्रावर वातावरण नाही
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('अंतराळवीर', 'JJ'), ('चंद्रावर', 'NNP'), ('एकमेकांचे', 'NNP'), ('आवाज', 'NNP'), ('का', 'NNP'), ('ऐकू', 'NNP'), ('शकत', 'NNP'), ('नाहीत', 'NN')]
#          Named Entities (Marathi): (S
#   अंतराळवीर/JJ
#   चंद्रावर/NNP
#   एकमेकांचे/NNP
#   आवाज/NNP
#   का/NNP
#   ऐकू/NNP
#   शकत/NNP
#   नाहीत/NN)
#
# Question 26:
# Hindi - Student Response: ध्वनि क्या है
#        Model Answer:  ऊर्जा
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('ध्वनि', 'JJ'), ('क्या', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S ध्वनि/JJ क्या/NNP है/NN)
# Marathi - Student Response: ध्वनी काय आहे
#          Model Answer:  ऊर्जा
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('ध्वनी', 'JJ'), ('काय', 'NNP'), ('आहे', 'NN')]
#          Named Entities (Marathi): (S ध्वनी/JJ काय/NNP आहे/NN)
#
# Question 27:
# Hindi - Student Response: किस प्रकार की तरंग को आगे बढ़ने के लिए माध्यम की जरूरत नहीं होती
#        Model Answer:  विद्युत् चुम्बकीय तरंग
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('किस', 'JJ'), ('प्रकार', 'NNP'), ('की', 'NNP'), ('तरंग', 'NNP'), ('को', 'NNP'), ('आगे', 'NNP'), ('बढ़ने', 'NNP'), ('के', 'NNP'), ('लिए', 'NNP'), ('माध्यम', 'NNP'), ('की', 'NNP'), ('जरूरत', 'NNP'), ('नहीं', 'NNP'), ('होती', 'NN')]
#        Named Entities (Hindi): (S
#   किस/JJ
#   प्रकार/NNP
#   की/NNP
#   तरंग/NNP
#   को/NNP
#   आगे/NNP
#   बढ़ने/NNP
#   के/NNP
#   लिए/NNP
#   माध्यम/NNP
#   की/NNP
#   जरूरत/NNP
#   नहीं/NNP
#   होती/NN)
# Marathi - Student Response: कोणत्या तरंगाना पुढे जाण्यासाठी माध्यमाची गरज नसते
#          Model Answer:  विद्युत चुम्बकीय तरंग
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('कोणत्या', 'JJ'), ('तरंगाना', 'NNP'), ('पुढे', 'NNP'), ('जाण्यासाठी', 'NNP'), ('माध्यमाची', 'NNP'), ('गरज', 'NNP'), ('नसते', 'NN')]
#          Named Entities (Marathi): (S
#   कोणत्या/JJ
#   तरंगाना/NNP
#   पुढे/NNP
#   जाण्यासाठी/NNP
#   माध्यमाची/NNP
#   गरज/NNP
#   नसते/NN)
#
# Question 28:
# Hindi - Student Response: इंसानों की आवाज अलगअलग क्यों होती हैं
#        Model Answer:  आवृति अलग होने से तारत्व अलग होता है
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('इंसानों', 'JJ'), ('की', 'NNP'), ('आवाज', 'NNP'), ('अलगअलग', 'NNP'), ('क्यों', 'NNP'), ('होती', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S इंसानों/JJ की/NNP आवाज/NNP अलगअलग/NNP क्यों/NNP होती/NNP हैं/NN)
# Marathi - Student Response: माणसांचे आवाज वेगळे का असतात
#          Model Answer:  वारंवारता वेगवेगळी त्यामुळे उच्चनीचता वेगवेगळी
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('माणसांचे', 'JJ'), ('आवाज', 'NNP'), ('वेगळे', 'NNP'), ('का', 'NNP'), ('असतात', 'NN')]
#          Named Entities (Marathi): (S माणसांचे/JJ आवाज/NNP वेगळे/NNP का/NNP असतात/NN)
#
# Question 29:
# Hindi - Student Response: पानी की तीन अवस्थाएं क्या हैं
#        Model Answer:  बर्फ पानी भाप
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('पानी', 'JJ'), ('की', 'NNP'), ('तीन', 'NNP'), ('अवस्थाएं', 'NNP'), ('क्या', 'NNP'), ('हैं', 'NN')]
#        Named Entities (Hindi): (S पानी/JJ की/NNP तीन/NNP अवस्थाएं/NNP क्या/NNP हैं/NN)
# Marathi - Student Response: पाण्याच्या तीन अवस्था कोणत्या
#          Model Answer:  बर्फ पाणी वाफ
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('पाण्याच्या', 'JJ'), ('तीन', 'NNP'), ('अवस्था', 'NNP'), ('कोणत्या', 'NN')]
#          Named Entities (Marathi): (S पाण्याच्या/JJ तीन/NNP अवस्था/NNP कोणत्या/NN)
#
# Question 30:
# Hindi - Student Response: बर्फ पानी पर तैरती क्यों है
#        Model Answer:  बर्फ का घनत्व पानी के घनत्व से कम होता है
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('बर्फ', 'JJ'), ('पानी', 'NNP'), ('पर', 'NNP'), ('तैरती', 'NNP'), ('क्यों', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S बर्फ/JJ पानी/NNP पर/NNP तैरती/NNP क्यों/NNP है/NN)
# Marathi - Student Response: बर्फ पाण्यावर का तरंगतो
#          Model Answer:  बर्फाची घनता पाण्यापेक्षा कमी असते
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('बर्फ', 'JJ'), ('पाण्यावर', 'NNP'), ('का', 'NNP'), ('तरंगतो', 'NN')]
#          Named Entities (Marathi): (S बर्फ/JJ पाण्यावर/NNP का/NNP तरंगतो/NN)
#
# Question 31:
# Hindi - Student Response: समुद्र का पानी खारा क्यों होता है
#        Model Answer:  नदियों से आए पानी में पत्थरों के लवण घुले होते हैं
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('समुद्र', 'JJ'), ('का', 'NNP'), ('पानी', 'NNP'), ('खारा', 'NNP'), ('क्यों', 'NNP'), ('होता', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S समुद्र/JJ का/NNP पानी/NNP खारा/NNP क्यों/NNP होता/NNP है/NN)
# Marathi - Student Response: समुद्राचे पाणी खारे का असते
#          Model Answer:  खडकांचे क्षार नद्यांच्या पाण्यामध्ये विरघळून वाहून येतात
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('समुद्राचे', 'JJ'), ('पाणी', 'NNP'), ('खारे', 'NNP'), ('का', 'NNP'), ('असते', 'NN')]
#          Named Entities (Marathi): (S समुद्राचे/JJ पाणी/NNP खारे/NNP का/NNP असते/NN)
#
# Question 32:
# Hindi - Student Response: वाष्पोत्सर्जन क्या है
#        Model Answer:  पत्तों का रंध्रों से पानी खोना
#        Hindi Score: 0
#        Hindi Mistakes: []
#        POS Tags (Hindi): [('वाष्पोत्सर्जन', 'JJ'), ('क्या', 'NNP'), ('है', 'NN')]
#        Named Entities (Hindi): (S वाष्पोत्सर्जन/JJ क्या/NNP है/NN)
# Marathi - Student Response: बाष्पोत्सर्जन   म्हणजे   काय ?
#          Model Answer: झाडाच्या पर्णरंध्रांमधून बाष्परुपात पाणी बाहेर पडणे
#          Marathi Score: 0
#          Marathi Mistakes: []
#          POS Tags (Marathi): [('बाष्पोत्सर्जन', 'JJ'), ('म्हणजे', 'NNP'), ('काय', 'NN'), ('?', '.')]
#          Named Entities (Marathi): (S बाष्पोत्सर्जन/JJ म्हणजे/NNP काय/NN ?/.)

# %% [markdown]
# #  Grading Student Responses

# %% [markdown]
# The set of words that are present in the student response but not in the model answer. In this case, it includes:{} or (0, []) represents a perfect match between the student's response and the model answer, indicating no errors found during evaluation.

# %%
for index, row in df.iterrows():
    
    # Extract student response and model answer for each question
    qno = row['Qno']
    student_response_hindi = row['Question in Hindi']
    model_answer_hindi = row['Model Answer in Hindi']
    student_response_marathi = row['Question in Marathi']
    model_answer_marathi = row['Model Answer in Marathi']
    
    score_hindi = grade_response(student_response_hindi, model_answer_hindi)
    score_marathi = grade_response(student_response_marathi, model_answer_marathi)
    
    print(f"Question {qno}:")
    print("Hindi - Student Response:", student_response_hindi)
    print("       Model Answer:", model_answer_hindi)
    print("       Hindi Score:", score_hindi)
    print("Marathi - Student Response:", student_response_marathi)
    print("         Model Answer:", model_answer_marathi)
    print("         Marathi Score:", score_marathi)
    print()
# Out:
# Question 1:
# Hindi - Student Response: कीड़ों की आंखों को संयुक्त आंखें क्यों कहा जाता है
#        Model Answer:  उनकी आंखों में हजारों लेंस होते हैं
#        Hindi Score: (0, [])
# Marathi - Student Response: कीटकांच्या डोळ्यांना संयुक्त डोळे का म्हणतात
#          Model Answer:  त्यांच्या डोळ्यात हजारो भिंग असतात
#          Marathi Score: (0, [])
#
# Question 2:
# Hindi - Student Response: छलावरण का उपयोग किस लिए किया जाता है
#        Model Answer:  छिपकर शिकार करने के लिए शिकारियों से खुद को बचाने के लिए
#        Hindi Score: (0, [])
# Marathi - Student Response: छ्द्मावरणाचा उपयोग प्राणी कशासाठी करतात?
#          Model Answer: स्वसंरक्षण आणि  शिकार
#          Marathi Score: (0, [])
#
# Question 3:
# Hindi - Student Response: कुछ फूलों पर रंगीन डिज़ाइन क्यों होता है
#        Model Answer:  ताकि कीड़ों को फूलों में मौजूद रस तक पहुँचने का रास्ता दिखे
#        Hindi Score: (0, [])
# Marathi - Student Response: काही फुलांवर रंगीबेरंगी नक्षी का असते
#          Model Answer:  कीटकांना फुलातील रसाचा रस्ता दाखवण्यासाठी
#          Marathi Score: (0, [])
#
# Question 4:
# Hindi - Student Response: रेगिस्तान में कम पानी में भी जिंदा रहने के लिए पौधों में क्या बदलाव हुआ है
#        Model Answer:  पत्ते कांटों में बदल गए हैं
#        Hindi Score: (0, [])
# Marathi - Student Response: वाळवंटातील झाडांनी कमी पाण्यात जगण्यासाठी पानांमध्ये काय बदल केला
#          Model Answer:  पानांचे रुपांतर काट्यात झाले
#          Marathi Score: (0, [])
#
# Question 5:
# Hindi - Student Response: प्लेटलेट की संख्या कम हो जाने से क्या होगा
#        Model Answer:  जख्म होने पर थक्के ना ज़मने के कारण बहाव ज्यादा होगा
#        Hindi Score: (0, [])
# Marathi - Student Response: रक्तातील कोणता घटक ऑक्सिजन वाहून नेण्याचे काम करतो
#          Model Answer:  लाल रक्तपेशी
#          Marathi Score: (0, [])
#
# Question 6:
# Hindi - Student Response: रक्त का कौनसा घटक ऑक्सीजन का वहन करता है
#        Model Answer:  लाल रक्त कणिका
#        Hindi Score: (0, [])
# Marathi - Student Response: रक्तातील कोणत्या घटकात मुख्यतः क्षार, प्रथिने, साखर, अन्य पोषकतत्वे असतात
#          Model Answer:  प्लाज्मा
#          Marathi Score: (0, [])
#
# Question 7:
# Hindi - Student Response: रक्त के किस हिस्से में मुख्यतः विटामिन, खनिज और कार्बोहाइड्रेट होता है
#        Model Answer:  प्लाज्मा
#        Hindi Score: (0, [])
# Marathi - Student Response: प्लेटलेटची संख्या कमी झाली तर काय होईल
#          Model Answer:  जखम झाल्यावर रक्ताच्या गुठळ्या होणार नाहीत आणि जास्त रक्तस्त्राव होईल
#          Marathi Score: (0, [])
#
# Question 8:
# Hindi - Student Response: ह्रदय को रक्त पहुंचाने वाली रक्तवाहिनी बंद हो जाने से दिल का दौरा पड़ सकता है, क्यों
#        Model Answer:  रक्त में घुली ऑक्सीजन और पोषक तत्व ह्रदय के उस हिस्से तक नहीं पहुंचते हैं
#        Hindi Score: (0, [])
# Marathi - Student Response: हृदयाला रक्त पुरवठा करणारी रक्तवाहिनी बंद पडल्यावर हार्ट ॲटॅक येऊ शकतो, कारण
#          Model Answer:  रक्तातील ऑक्सिजन आणि पोषणतत्वे हृदयाच्या त्या भागापर्यंत पोहचू शकत नाही
#          Marathi Score: (0, [])
#
# Question 9:
# Hindi - Student Response: आंखों में धूल चली जाने पर आंसू क्यों आ जाते हैं
#        Model Answer:  धूल के कण आंसुओं के साथ बाहर निकल आते है ताकि आंखों को हानि न पंहुचे
#        Hindi Score: (0, [])
# Marathi - Student Response: डोळ्यात धुळ गेल्या नंतर डोळ्यातून अश्रु का येतात
#          Model Answer:  अश्रुंबरोबर धुळीचे कण वाहून जातात त्यामुळे डोळ्यांना नुकसान पोहचत नाही
#          Marathi Score: (0, [])
#
# Question 10:
# Hindi - Student Response: प्रकाश किरणें सबसे पहले आंख के किस भाग से गुजरती हैं
#        Model Answer:  स्वच्छ मंडल कार्निया
#        Hindi Score: (0, [])
# Marathi - Student Response: डोळ्याच्या कोणत्या भागातून परावर्तित प्रकाश किरणे सर्वात आधी जातात
#          Model Answer:  पारपटल कॉर्निया
#          Marathi Score: (0, [])
#
# Question 11:
# Hindi - Student Response: वस्तु का सफ़ेद होना क्या दर्शाता है
#        Model Answer:  वह सभी रंगों को परावर्तित करती है
#        Hindi Score: (0, [])
# Marathi - Student Response: वस्तू दिसण्यासाठी आपल्याला प्रकाशाच्या कोणत्या गुणधर्माची मदत होते
#          Model Answer:  प्रकाशाचे परावर्तन
#          Marathi Score: (0, [])
#
# Question 12:
# Hindi - Student Response: हर्मन स्नेलेन ने किसका आविष्कार किया था
#        Model Answer:  स्नेलेन चार्ट
#        Hindi Score: (0, [])
# Marathi - Student Response: हर्मन स्नेलेन यांनी कशाचा शोध लावला होता
#          Model Answer:  स्नेलेन चार्ट
#          Marathi Score: (0, [])
#
# Question 13:
# Hindi - Student Response: गर्म चाय का कप कुछ समय बाद ठंडा क्यों हो जाता है
#        Model Answer:  ऊष्मा गर्म से ठंडी की ओर गति करती है
#        Hindi Score: (0, [])
# Marathi - Student Response: गरम चहाचा कप काही वेळेनंतर थंड का होतो
#          Model Answer:  उष्णता गरम वस्तू कडून थंड वस्तू कडे जाते
#          Marathi Score: (0, [])
#
# Question 14:
# Hindi - Student Response: कोयले के एक टुकड़े में आग लगाने से बाकी टुकड़े भी क्यों सुलग जाते हैं
#        Model Answer:  चालन से ऊष्मा सभी टुकड़ों में फ़ैल जाती है
#        Hindi Score: (0, [])
# Marathi - Student Response: एक कोळसा पेटला तर उरलेले कोळसे ही का पेटतात
#          Model Answer:  वहनामुळे उष्णता सर्व कोळश्यांमध्ये पसरते
#          Marathi Score: (0, [])
#
# Question 15:
# Hindi - Student Response: द्रव और गैस में ऊष्मा स्थानान्तरण की प्रक्रिया को क्या कहते हैं
#        Model Answer:  संवहन
#        Hindi Score: (0, [])
# Marathi - Student Response: द्रव आणि वायूमध्ये होणाऱ्या उष्णता स्थानांतरणाच्या प्रक्रियेला काय म्हणतात
#          Model Answer:  अभिसरण
#          Marathi Score: (0, [])
#
# Question 16:
# Hindi - Student Response: कपड़े कौनसी प्रक्रिया से सूखते हैं
#        Model Answer:  वाष्पन
#        Hindi Score: (0, [])
# Marathi - Student Response: कपडे कोणत्या प्रक्रियेमुळे वाळतात
#          Model Answer:  बाष्पीभवन
#          Marathi Score: (0, [])
#
# Question 17:
# Hindi - Student Response: पहाड़ पर चढ़ने के लिए सीधे रास्ते के बजाय हमेशा घुमावदार रास्ता क्यों बनाते हैं
#        Model Answer:  इससे रास्ते का झुकाव कम होकर चढ़ने में कम मेहनत लगती है
#        Hindi Score: (0, [])
# Marathi - Student Response: घाटातले रस्ते नेहमी वळणावळणाचे असतात, कारण त्यामुळे
#          Model Answer:  रस्त्याचा कोन कमी होतो आणि कमी मेहनतीत वर चढता येते
#          Marathi Score: (0, [])
#
# Question 18:
# Hindi - Student Response: उत्तोलक कितने प्रकार के होते हैं
#        Model Answer:  तीन
#        Hindi Score: (0, [])
# Marathi - Student Response: तरफेचे प्रकार किती
#          Model Answer:  तीन
#          Marathi Score: (0, [])
#
# Question 19:
# Hindi - Student Response: उत्तोलक में जिस भुजा से प्रयास लगाया जाता है उसे क्या कहते हैं
#        Model Answer:  प्रयास भुजा
#        Hindi Score: (0, [])
# Marathi - Student Response: तरफेमध्ये ज्या बाजूने बल लावले जाते त्या बाजूला काय म्हणतात
#          Model Answer:  बलभुजा
#          Marathi Score: (0, [])
#
# Question 20:
# Hindi - Student Response: बिट्टू को घिरनी का इस्तेमाल करके 50 किलो की वस्तु को कम से कम बल लगाकर उठाना है. वह क्या करेगा
#        Model Answer:  स्थिर घिरनी के साथ एक से ज्यादा खिसकने वाली घिरनियों का इस्तेमाल
#        Hindi Score: (0, [])
# Marathi - Student Response: बिट्टूला कमीत-कमी बल लावून कप्पीच्या मदतीने 50 किलोची वस्तू उचलायची आहे. तो काय बरं करेल
#          Model Answer:  स्थिर कप्पीसोबत एकपेक्षा जास्त चल कप्प्या लावेल
#          Marathi Score: (0, [])
#
# Question 21:
# Hindi - Student Response: मानव कंकाल किससे बना होता है
#        Model Answer:  हड्डियों से
#        Hindi Score: (0, [])
# Marathi - Student Response: मानवी सांगाडा कशाचा बनलेला आहे
#          Model Answer:  हाडांचा
#          Marathi Score: (0, [])
#
# Question 22:
# Hindi - Student Response: हड्डियों के बींच जोड़ नहीं होते तो क्या होता
#        Model Answer:  हिलना डुलना असंभव होता
#        Hindi Score: (0, [])
# Marathi - Student Response: हाडांमध्ये सांधे नसते तर
#          Model Answer:  हालचाल करणे अशक्य झाले असते
#          Marathi Score: (0, [])
#
# Question 23:
# Hindi - Student Response: एक वयस्क मनुष्य के कंकाल का वजन लगभग कितना होता है
#        Model Answer:  दस किग्रा
#        Hindi Score: (0, [])
# Marathi - Student Response: एका प्रौढ व्यक्तीच्या सांगाड्याचे वजन अंदाजे किती असते
#          Model Answer:  दस किग्रॅ
#          Marathi Score: (0, [])
#
# Question 24:
# Hindi - Student Response: हम पैर को गोल क्यों हिला पाते हैं
#        Model Answer:  फीमर और श्रोणी के बॉल एंड सॉकेट जोड़ की वजह से
#        Hindi Score: (0, [])
# Marathi - Student Response: आपण आपला पाय गोलाकार कशामुळे हलवू शकतो
#          Model Answer:  फीमर आणि श्रोणी यांतील बॉल आणि सॉकेट सांधा
#          Marathi Score: (0, [])
#
# Question 25:
# Hindi - Student Response: चाँद पर कोई किसी की आवाज क्यों नहीं सुन सकते
#        Model Answer:  वायुमंडल ना होने के कारण
#        Hindi Score: (0, [])
# Marathi - Student Response: अंतराळवीर चंद्रावर एकमेकांचे आवाज का ऐकू शकत नाहीत
#          Model Answer:  कारण चंद्रावर वातावरण नाही
#          Marathi Score: (0, [])
#
# Question 26:
# Hindi - Student Response: ध्वनि क्या है
#        Model Answer:  ऊर्जा
#        Hindi Score: (0, [])
# Marathi - Student Response: ध्वनी काय आहे
#          Model Answer:  ऊर्जा
#          Marathi Score: (0, [])
#
# Question 27:
# Hindi - Student Response: किस प्रकार की तरंग को आगे बढ़ने के लिए माध्यम की जरूरत नहीं होती
#        Model Answer:  विद्युत् चुम्बकीय तरंग
#        Hindi Score: (0, [])
# Marathi - Student Response: कोणत्या तरंगाना पुढे जाण्यासाठी माध्यमाची गरज नसते
#          Model Answer:  विद्युत चुम्बकीय तरंग
#          Marathi Score: (0, [])
#
# Question 28:
# Hindi - Student Response: इंसानों की आवाज अलगअलग क्यों होती हैं
#        Model Answer:  आवृति अलग होने से तारत्व अलग होता है
#        Hindi Score: (0, [])
# Marathi - Student Response: माणसांचे आवाज वेगळे का असतात
#          Model Answer:  वारंवारता वेगवेगळी त्यामुळे उच्चनीचता वेगवेगळी
#          Marathi Score: (0, [])
#
# Question 29:
# Hindi - Student Response: पानी की तीन अवस्थाएं क्या हैं
#        Model Answer:  बर्फ पानी भाप
#        Hindi Score: (0, [])
# Marathi - Student Response: पाण्याच्या तीन अवस्था कोणत्या
#          Model Answer:  बर्फ पाणी वाफ
#          Marathi Score: (0, [])
#
# Question 30:
# Hindi - Student Response: बर्फ पानी पर तैरती क्यों है
#        Model Answer:  बर्फ का घनत्व पानी के घनत्व से कम होता है
#        Hindi Score: (0, [])
# Marathi - Student Response: बर्फ पाण्यावर का तरंगतो
#          Model Answer:  बर्फाची घनता पाण्यापेक्षा कमी असते
#          Marathi Score: (0, [])
#
# Question 31:
# Hindi - Student Response: समुद्र का पानी खारा क्यों होता है
#        Model Answer:  नदियों से आए पानी में पत्थरों के लवण घुले होते हैं
#        Hindi Score: (0, [])
# Marathi - Student Response: समुद्राचे पाणी खारे का असते
#          Model Answer:  खडकांचे क्षार नद्यांच्या पाण्यामध्ये विरघळून वाहून येतात
#          Marathi Score: (0, [])
#
# Question 32:
# Hindi - Student Response: वाष्पोत्सर्जन क्या है
#        Model Answer:  पत्तों का रंध्रों से पानी खोना
#        Hindi Score: (0, [])
# Marathi - Student Response: बाष्पोत्सर्जन   म्हणजे   काय ?
#          Model Answer: झाडाच्या पर्णरंध्रांमधून बाष्परुपात पाणी बाहेर पडणे
#          Marathi Score: (0, [])

# %%
for index, row in df.iterrows():

    student_response_hindi = row['Question in Hindi']
    model_answer_hindi = row['Model Answer in Hindi']

    score_hindi = grade_response(student_response_hindi, model_answer_hindi)
    scores.append(score_hindi)

# %%
# Creating datasets
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_dataset = CustomDataset(train_encodings, train_labels)
val_dataset = CustomDataset(val_encodings, val_labels)

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
optimizer = AdamW(model.parameters(), lr=5e-5)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\ANESTHESIA\anaconda3\lib\site-packages\transformers\optimization.py:457: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# # Hardware Selection

# %%
# Check if GPU is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
for epoch in range(3):  
    model.train()
    for batch in train_loader:
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
# Out:
# C:\Users\ANESTHESIA\AppData\Local\Temp\ipykernel_13712\2210648296.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(self.labels[idx])

# %% [markdown]
# # Evaluating the model

# %%
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=False)

model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for batch in val_loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        outputs = model(input_ids, attention_mask=attention_mask)
        predicted = torch.argmax(outputs.logits, dim=1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()


if total == 0:
    accuracy = "Undefined"
else:
    accuracy = int(correct / total * 100)  # Convert accuracy to an integer percentage
print(f'Accuracy: {accuracy}')
# Out:
# C:\Users\ANESTHESIA\AppData\Local\Temp\ipykernel_13712\875721199.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(self.labels[idx])
# Accuracy: 100
